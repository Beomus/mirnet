# %%
import tensorflow as tf

print(f"TensorFlow has access to the following devices:\n{tf.config.list_physical_devices()}")
print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow has access to the following devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow version: 2.7.0

# %%
import os
import cv2
import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

# %%
# import gdown

# url = 'https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6'
# output = 'lol_dataset.zip'
# gdown.download(url, output, quiet=False)

# %%
# !unzip -q lol_dataset.zip

# %%
random.seed(8)

IMAGE_SIZE = 128
BATCH_SIZE = 2
MAX_TRAIN_IMAGES = 300

# %%
def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.cast(image, dtype=tf.float32) / 255.0
    return image


def random_crop(low_image, enhanced_image):
    low_image_shape = tf.shape(low_image)[:2]
    low_w = tf.random.uniform(
        shape=(), maxval=low_image_shape[1] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_h = tf.random.uniform(
        shape=(), maxval=low_image_shape[0] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    enhanced_w = low_w
    enhanced_h = low_h
    low_image_cropped = low_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    enhanced_image_cropped = enhanced_image[
        enhanced_h : enhanced_h + IMAGE_SIZE, enhanced_w : enhanced_w + IMAGE_SIZE
    ]
    return low_image_cropped, enhanced_image_cropped


def load_data(low_light_image_path, enhanced_image_path):
    low_light_image = read_image(low_light_image_path)
    enhanced_image = read_image(enhanced_image_path)
    low_light_image, enhanced_image = random_crop(low_light_image, enhanced_image)
    return low_light_image, enhanced_image


def get_dataset(low_light_images, enhanced_images):
    dataset = tf.data.Dataset.from_tensor_slices((low_light_images, enhanced_images))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset

# %%
train_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[:MAX_TRAIN_IMAGES]
train_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[:MAX_TRAIN_IMAGES]

val_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[MAX_TRAIN_IMAGES:]
val_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[MAX_TRAIN_IMAGES:]

test_low_light_images = sorted(glob("./lol_dataset/eval15/low/*"))
test_enhanced_images = sorted(glob("./lol_dataset/eval15/high/*"))


train_dataset = get_dataset(train_low_light_images, train_enhanced_images)
val_dataset = get_dataset(val_low_light_images, val_enhanced_images)


print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
#
# Train Dataset: <BatchDataset shapes: ((2, None, None, 3), (2, None, None, 3)), types: (tf.float32, tf.float32)>
# Val Dataset: <BatchDataset shapes: ((2, None, None, 3), (2, None, None, 3)), types: (tf.float32, tf.float32)>
# 2022-01-06 11:48:43.522389: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-01-06 11:48:43.522861: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### MIRNet Model
# Here are the main features of the MIRNet model:
#
# - A feature extraction model that computes a complementary set of features across multiple spatial scales, while maintaining the original high-resolution features to preserve precise spatial details.
#
# - A regularly repeated mechanism for information exchange, where the features across multi-resolution branches are progressively fused together for improved representation learning.
#
# - A new approach to fuse multi-scale features using a selective kernel network that dynamically combines variable receptive fields and faithfully preserves the original feature information at each spatial resolution.
#
# - A recursive residual design that progressively breaks down the input signal in order to simplify the overall learning process, and allows the construction of very deep networks.

# %% [markdown]
# #### Selective Kernel Feature Fusion
#
# The Selective Kernel Feature Fusion or SKFF module performs dynamic adjustment of receptive fields via two operations: Fuse and Select. The Fuse operator generates global feature descriptors by combining the information from multi-resolution streams. The Select operator uses these descriptors to recalibrate the feature maps (of different streams) followed by their aggregation.
#
# **Fuse:** The SKFF receives inputs from three parallel convolution streams carrying different scales of information. We first combine these multi-scale features using an element-wise sum, on which we apply Global Average Pooling (GAP) across the spatial dimension. Next, we apply a channel- downscaling convolution layer to generate a compact feature representation which passes through three parallel channel-upscaling convolution layers (one for each resolution stream) and provides us with three feature descriptors.
#
# **Select:** This operator applies the softmax function to the feature descriptors to obtain the corresponding activations that are used to adaptively recalibrate multi-scale feature maps. The aggregated features are defined as the sum of product of the corresponding multi-scale feature and the feature descriptor.

# %%
def selective_kernel_feature_fusion(
    multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3
):
    channels = list(multi_scale_feature_1.shape)[-1]

    combined_feature = layers.Add()(
        [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3]
    )

    gap = layers.GlobalAveragePooling2D()(combined_feature)
    channel_wise_statistics = tf.reshape(gap, shape=(-1, 1, 1, channels))
    compact_feature_representation = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(channel_wise_statistics)

    feature_descriptor_1 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)

    feature_descriptor_2 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)

    feature_descriptor_3 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)

    feature_1 = multi_scale_feature_1 * feature_descriptor_1
    feature_2 = multi_scale_feature_2 * feature_descriptor_2
    feature_3 = multi_scale_feature_3 * feature_descriptor_3

    aggregated_feature = layers.Add()([feature_1, feature_2, feature_3])
    
    return aggregated_feature

# %% [markdown]
# #### Dual Attention Unit
#
# The Dual Attention Unit or DAU is used to extract features in the convolutional streams. While the SKFF block fuses information across multi-resolution branches, we also need a mechanism to share information within a feature tensor, both along the spatial and the channel dimensions which is done by the DAU block. The DAU suppresses less useful features and only allows more informative ones to pass further. This feature recalibration is achieved by using Channel Attention and Spatial Attention mechanisms.
#
# The Channel Attention branch exploits the inter-channel relationships of the convolutional feature maps by applying squeeze and excitation operations. Given a feature map, the squeeze operation applies Global Average Pooling across spatial dimensions to encode global context, thus yielding a feature descriptor. The excitation operator passes this feature descriptor through two convolutional layers followed by the sigmoid gating and generates activations. Finally, the output of Channel Attention branch is obtained by rescaling the input feature map with the output activations.
#
# The Spatial Attention branch is designed to exploit the inter-spatial dependencies of convolutional features. The goal of Spatial Attention is to generate a spatial attention map and use it to recalibrate the incoming features. To generate the spatial attention map, the Spatial Attention branch first independently applies Global Average Pooling and Max Pooling operations on input features along the channel dimensions and concatenates the outputs to form a resultant feature map which is then passed through a convolution and sigmoid activation to obtain the spatial attention map. This spatial attention map is then used to rescale the input feature map.

# %%
def spatial_attention_block(input_tensor):
    average_pooling = tf.reduce_max(input_tensor, axis=-1)
    average_pooling = tf.expand_dims(average_pooling, axis=-1)
    max_pooling = tf.reduce_mean(input_tensor, axis=-1)
    max_pooling = tf.expand_dims(max_pooling, axis=-1)
    concatenated = layers.Concatenate(axis=-1)([average_pooling, max_pooling])
    feature_map = layers.Conv2D(1, kernel_size=(1, 1))(concatenated)
    feature_map = tf.nn.sigmoid(feature_map)
    
    return input_tensor * feature_map


def channel_attention_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    average_pooling = layers.GlobalAveragePooling2D()(input_tensor)
    feature_descriptor = tf.reshape(average_pooling, shape=(-1, 1, 1, channels))

    feature_activations = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(feature_descriptor)

    feature_activations = layers.Conv2D(
        filters=channels, kernel_size=(1, 1), activation="sigmoid"
    )(feature_activations)

    return input_tensor * feature_activations


def dual_attention_unit_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    feature_map = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(input_tensor)

    feature_map = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(feature_map)

    channel_attention = channel_attention_block(feature_map)
    spatial_attention = spatial_attention_block(feature_map)
    concatenation = layers.Concatenate(axis=-1)([channel_attention, spatial_attention])
    concatenation = layers.Conv2D(channels, kernel_size=(1, 1))(concatenation)

    return layers.Add()([input_tensor, concatenation])

# %% [markdown]
# #### Multi-Scale Residual Block
#
# The Multi-Scale Residual Block is capable of generating a spatially-precise output by maintaining high-resolution representations, while receiving rich contextual information from low-resolutions. The MRB consists of multiple (three in this paper) fully-convolutional streams connected in parallel. It allows information exchange across parallel streams in order to consolidate the high-resolution features with the help of low-resolution features, and vice versa. The MIRNet employs a recursive residual design (with skip connections) to ease the flow of information during the learning process. In order to maintain the residual nature of our architecture, residual resizing modules are used to perform downsampling and upsampling operations that are used in the Multi-scale Residual Block.

# %%
def down_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(input_tensor)

    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)

    main_branch = layers.MaxPooling2D()(main_branch)
    main_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.MaxPooling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(skip_branch)

    return layers.Add()([skip_branch, main_branch])


def up_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(input_tensor)

    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    
    main_branch = layers.UpSampling2D()(main_branch)
    main_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.UpSampling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(skip_branch)

    return layers.Add()([skip_branch, main_branch])

# %%
def multi_scale_residual_block(input_tensor, channels):
    # features
    level1 = input_tensor
    level2 = down_sampling_module(input_tensor)
    level3 = down_sampling_module(level2)

    # DAU
    level1_dau = dual_attention_unit_block(level1)
    level2_dau = dual_attention_unit_block(level2)
    level3_dau = dual_attention_unit_block(level3)

    # SKFF
    level1_skff = selective_kernel_feature_fusion(
        level1_dau,
        up_sampling_module(level2_dau),
        up_sampling_module(up_sampling_module(level3_dau)),
    )
    level2_skff = selective_kernel_feature_fusion(
        down_sampling_module(level1_dau), level2_dau, up_sampling_module(level3_dau)
    )
    level3_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(level1_dau)),
        down_sampling_module(level2_dau),
        level3_dau,
    )

    # DAU 2
    level1_dau_2 = dual_attention_unit_block(level1_skff)
    level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
    level3_dau_2 = up_sampling_module(
        up_sampling_module(dual_attention_unit_block(level3_skff))
    )

    # SKFF 2
    skff_ = selective_kernel_feature_fusion(level1_dau_2, level3_dau_2, level3_dau_2)
    conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
    
    return layers.Add()([input_tensor, conv])

# %%
def recursive_residual_group(input_tensor, num_mrb, channels):
    conv1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_mrb):
        conv1 = multi_scale_residual_block(conv1, channels)
    conv2 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(conv1)

    return layers.Add()([conv2, input_tensor])


def mirnet_model(num_rrg, num_mrb, channels):
    input_tensor = keras.Input(shape=[None, None, 3])
    x1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_rrg):
        x1 = recursive_residual_group(x1, num_mrb, channels)
    conv = layers.Conv2D(3, kernel_size=(3, 3), padding="same")(x1)
    output_tensor = layers.Add()([input_tensor, conv])
    
    return keras.Model(input_tensor, output_tensor)

# %%
model = mirnet_model(num_rrg=3, num_mrb=2, channels=64)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   1792        ['input_1[0][0]']
#                                 64)
#
#  conv2d_1 (Conv2D)              (None, None, None,   36928       ['conv2d[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   36928       ['conv2d_1[0][0]']
#                                 64)
#
#  conv2d_2 (Conv2D)              (None, None, None,   4160        ['conv2d_1[0][0]']
#                                 64)
#
#  conv2d_11 (Conv2D)             (None, None, None,   36928       ['conv2d_10[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   36928       ['conv2d_2[0][0]']
#                                 64)
#
#  tf.math.reduce_max (TFOpLambda  (None, None, None)  0           ['conv2d_11[0][0]']
#  )
#
#  tf.math.reduce_mean (TFOpLambd  (None, None, None)  0           ['conv2d_11[0][0]']
#  a)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['conv2d_1[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['conv2d_3[0][0]']
#                                 64)
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['conv2d_11[0][0]']
#  alAveragePooling2D)
#
#  tf.expand_dims (TFOpLambda)    (None, None, None,   0           ['tf.math.reduce_max[0][0]']
#                                 1)
#
#  tf.expand_dims_1 (TFOpLambda)  (None, None, None,   0           ['tf.math.reduce_mean[0][0]']
#                                 1)
#
#  conv2d_5 (Conv2D)              (None, None, None,   8320        ['max_pooling2d_1[0][0]']
#                                 128)
#
#  conv2d_4 (Conv2D)              (None, None, None,   8320        ['max_pooling2d[0][0]']
#                                 128)
#
#  tf.reshape (TFOpLambda)        (None, 1, 1, 64)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  concatenate (Concatenate)      (None, None, None,   0           ['tf.expand_dims[0][0]',
#                                 2)                                'tf.expand_dims_1[0][0]']
#
#  add (Add)                      (None, None, None,   0           ['conv2d_5[0][0]',
#                                 128)                              'conv2d_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 1, 1, 8)      520         ['tf.reshape[0][0]']
#
#  conv2d_14 (Conv2D)             (None, None, None,   3           ['concatenate[0][0]']
#                                 1)
#
#  conv2d_16 (Conv2D)             (None, None, None,   147584      ['add[0][0]']
#                                 128)
#
#  conv2d_6 (Conv2D)              (None, None, None,   16512       ['add[0][0]']
#                                 128)
#
#  conv2d_13 (Conv2D)             (None, 1, 1, 64)     576         ['conv2d_12[0][0]']
#
#  tf.math.sigmoid (TFOpLambda)   (None, None, None,   0           ['conv2d_14[0][0]']
#                                 1)
#
#  conv2d_17 (Conv2D)             (None, None, None,   147584      ['conv2d_16[0][0]']
#                                 128)
#
#  conv2d_7 (Conv2D)              (None, None, None,   147584      ['conv2d_6[0][0]']
#                                 128)
#
#  tf.math.multiply (TFOpLambda)  (None, None, None,   0           ['conv2d_11[0][0]',
#                                 64)                               'conv2d_13[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, None, None,   0          ['conv2d_11[0][0]',
#  )                              64)                               'tf.math.sigmoid[0][0]']
#
#  tf.math.reduce_max_1 (TFOpLamb  (None, None, None)  0           ['conv2d_17[0][0]']
#  da)
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, None, None)  0           ['conv2d_17[0][0]']
#  bda)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, None, None,   0          ['add[0][0]']
#                                 128)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['conv2d_7[0][0]']
#                                 128)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['tf.math.multiply[0][0]',
#                                 128)                              'tf.math.multiply_1[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['conv2d_17[0][0]']
#  obalAveragePooling2D)
#
#  tf.expand_dims_2 (TFOpLambda)  (None, None, None,   0           ['tf.math.reduce_max_1[0][0]']
#                                 1)
#
#  tf.expand_dims_3 (TFOpLambda)  (None, None, None,   0           ['tf.math.reduce_mean_1[0][0]']
#                                 1)
#
#  conv2d_9 (Conv2D)              (None, None, None,   33024       ['max_pooling2d_3[0][0]']
#                                 256)
#
#  conv2d_8 (Conv2D)              (None, None, None,   33024       ['max_pooling2d_2[0][0]']
#                                 256)
#
#  conv2d_15 (Conv2D)             (None, None, None,   8256        ['concatenate_1[0][0]']
#                                 64)
#
#  tf.reshape_1 (TFOpLambda)      (None, 1, 1, 128)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['tf.expand_dims_2[0][0]',
#                                 2)                                'tf.expand_dims_3[0][0]']
#
#  add_1 (Add)                    (None, None, None,   0           ['conv2d_9[0][0]',
#                                 256)                              'conv2d_8[0][0]']
#
#  add_2 (Add)                    (None, None, None,   0           ['conv2d_1[0][0]',
#                                 64)                               'conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 1, 1, 16)     2064        ['tf.reshape_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, None, None,   3           ['concatenate_2[0][0]']
#                                 1)
#
#  conv2d_22 (Conv2D)             (None, None, None,   590080      ['add_1[0][0]']
#                                 256)
#
#  conv2d_19 (Conv2D)             (None, 1, 1, 128)    2176        ['conv2d_18[0][0]']
#
#  tf.math.sigmoid_1 (TFOpLambda)  (None, None, None,   0          ['conv2d_20[0][0]']
#                                 1)
#
#  conv2d_23 (Conv2D)             (None, None, None,   590080      ['conv2d_22[0][0]']
#                                 256)
#
#  conv2d_56 (Conv2D)             (None, None, None,   4160        ['add_2[0][0]']
#                                 64)
#
#  tf.math.multiply_2 (TFOpLambda  (None, None, None,   0          ['conv2d_17[0][0]',
#  )                              128)                              'conv2d_19[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, None, None,   0          ['conv2d_17[0][0]',
#  )                              128)                              'tf.math.sigmoid_1[0][0]']
#
#  tf.math.reduce_max_2 (TFOpLamb  (None, None, None)  0           ['conv2d_23[0][0]']
#  da)
#
#  tf.math.reduce_mean_2 (TFOpLam  (None, None, None)  0           ['conv2d_23[0][0]']
#  bda)
#
#  conv2d_57 (Conv2D)             (None, None, None,   36928       ['conv2d_56[0][0]']
#                                 64)
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['tf.math.multiply_2[0][0]',
#                                 256)                              'tf.math.multiply_3[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 256)         0           ['conv2d_23[0][0]']
#  obalAveragePooling2D)
#
#  tf.expand_dims_4 (TFOpLambda)  (None, None, None,   0           ['tf.math.reduce_max_2[0][0]']
#                                 1)
#
#  tf.expand_dims_5 (TFOpLambda)  (None, None, None,   0           ['tf.math.reduce_mean_2[0][0]']
#                                 1)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, None, None,   0          ['add_2[0][0]']
#                                 64)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, None, None,   0          ['conv2d_57[0][0]']
#                                 64)
#
#  conv2d_21 (Conv2D)             (None, None, None,   32896       ['concatenate_3[0][0]']
#                                 128)
#
#  tf.reshape_2 (TFOpLambda)      (None, 1, 1, 256)    0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  concatenate_4 (Concatenate)    (None, None, None,   0           ['tf.expand_dims_4[0][0]',
#                                 2)                                'tf.expand_dims_5[0][0]']
#
#  conv2d_59 (Conv2D)             (None, None, None,   8320        ['max_pooling2d_7[0][0]']
#                                 128)
#
#  conv2d_58 (Conv2D)             (None, None, None,   8320        ['max_pooling2d_6[0][0]']
#                                 128)
#
#  add_3 (Add)                    (None, None, None,   0           ['add[0][0]',
#                                 128)                              'conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 1, 1, 32)     8224        ['tf.reshape_2[0][0]']
#
#  conv2d_26 (Conv2D)             (None, None, None,   3           ['concatenate_4[0][0]']
#                                 1)
#
#  add_14 (Add)                   (None, None, None,   0           ['conv2d_59[0][0]',
#                                 128)                              'conv2d_58[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_24[0][0]']
#
#  tf.math.sigmoid_2 (TFOpLambda)  (None, None, None,   0          ['conv2d_26[0][0]']
#                                 1)
#
#  conv2d_60 (Conv2D)             (None, None, None,   16512       ['add_14[0][0]']
#                                 128)
#
#  conv2d_64 (Conv2D)             (None, None, None,   16512       ['add_3[0][0]']
#                                 128)
#
#  tf.math.multiply_4 (TFOpLambda  (None, None, None,   0          ['conv2d_23[0][0]',
#  )                              256)                              'conv2d_25[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, None, None,   0          ['conv2d_23[0][0]',
#  )                              256)                              'tf.math.sigmoid_2[0][0]']
#
#  conv2d_61 (Conv2D)             (None, None, None,   147584      ['conv2d_60[0][0]']
#                                 128)
#
#  conv2d_65 (Conv2D)             (None, None, None,   147584      ['conv2d_64[0][0]']
#                                 128)
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['tf.math.multiply_4[0][0]',
#                                 512)                              'tf.math.multiply_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, None, None,   0          ['add_14[0][0]']
#                                 128)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, None, None,   0          ['conv2d_61[0][0]']
#                                 128)
#
#  max_pooling2d_11 (MaxPooling2D  (None, None, None,   0          ['add_3[0][0]']
#  )                              128)
#
#  max_pooling2d_10 (MaxPooling2D  (None, None, None,   0          ['conv2d_65[0][0]']
#  )                              128)
#
#  conv2d_27 (Conv2D)             (None, None, None,   131328      ['concatenate_5[0][0]']
#                                 256)
#
#  conv2d_63 (Conv2D)             (None, None, None,   33024       ['max_pooling2d_9[0][0]']
#                                 256)
#
#  conv2d_62 (Conv2D)             (None, None, None,   33024       ['max_pooling2d_8[0][0]']
#                                 256)
#
#  conv2d_67 (Conv2D)             (None, None, None,   33024       ['max_pooling2d_11[0][0]']
#                                 256)
#
#  conv2d_66 (Conv2D)             (None, None, None,   33024       ['max_pooling2d_10[0][0]']
#                                 256)
#
#  add_4 (Add)                    (None, None, None,   0           ['add_1[0][0]',
#                                 256)                              'conv2d_27[0][0]']
#
#  add_15 (Add)                   (None, None, None,   0           ['conv2d_63[0][0]',
#                                 256)                              'conv2d_62[0][0]']
#
#  add_16 (Add)                   (None, None, None,   0           ['conv2d_67[0][0]',
#                                 256)                              'conv2d_66[0][0]']
#
#  conv2d_32 (Conv2D)             (None, None, None,   65792       ['add_4[0][0]']
#                                 256)
#
#  add_17 (Add)                   (None, None, None,   0           ['add_15[0][0]',
#                                 256)                              'add_16[0][0]',
#                                                                   'add_4[0][0]']
#
#  conv2d_33 (Conv2D)             (None, None, None,   590080      ['conv2d_32[0][0]']
#                                 256)
#
#  global_average_pooling2d_5 (Gl  (None, 256)         0           ['add_17[0][0]']
#  obalAveragePooling2D)
#
#  up_sampling2d_3 (UpSampling2D)  (None, None, None,   0          ['add_4[0][0]']
#                                 256)
#
#  up_sampling2d_2 (UpSampling2D)  (None, None, None,   0          ['conv2d_33[0][0]']
#                                 256)
#
#  tf.reshape_5 (TFOpLambda)      (None, 1, 1, 256)    0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  conv2d_35 (Conv2D)             (None, None, None,   32896       ['up_sampling2d_3[0][0]']
#                                 128)
#
#  conv2d_34 (Conv2D)             (None, None, None,   32896       ['up_sampling2d_2[0][0]']
#                                 128)
#
#  conv2d_68 (Conv2D)             (None, 1, 1, 32)     8224        ['tf.reshape_5[0][0]']
#
#  add_6 (Add)                    (None, None, None,   0           ['conv2d_35[0][0]',
#                                 128)                              'conv2d_34[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_68[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_68[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_68[0][0]']
#
#  conv2d_28 (Conv2D)             (None, None, None,   16512       ['add_3[0][0]']
#                                 128)
#
#  conv2d_36 (Conv2D)             (None, None, None,   16512       ['add_6[0][0]']
#                                 128)
#
#  tf.math.multiply_12 (TFOpLambd  (None, None, None,   0          ['add_15[0][0]',
#  a)                             256)                              'conv2d_69[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, None, None,   0          ['add_16[0][0]',
#  a)                             256)                              'conv2d_70[0][0]']
#
#  tf.math.multiply_14 (TFOpLambd  (None, None, None,   0          ['add_4[0][0]',
#  a)                             256)                              'conv2d_71[0][0]']
#
#  conv2d_29 (Conv2D)             (None, None, None,   147584      ['conv2d_28[0][0]']
#                                 128)
#
#  conv2d_37 (Conv2D)             (None, None, None,   147584      ['conv2d_36[0][0]']
#                                 128)
#
#  add_18 (Add)                   (None, None, None,   0           ['tf.math.multiply_12[0][0]',
#                                 256)                              'tf.math.multiply_13[0][0]',
#                                                                   'tf.math.multiply_14[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, None, None,   0          ['add_3[0][0]']
#                                 128)
#
#  up_sampling2d (UpSampling2D)   (None, None, None,   0           ['conv2d_29[0][0]']
#                                 128)
#
#  up_sampling2d_5 (UpSampling2D)  (None, None, None,   0          ['add_6[0][0]']
#                                 128)
#
#  up_sampling2d_4 (UpSampling2D)  (None, None, None,   0          ['conv2d_37[0][0]']
#                                 128)
#
#  conv2d_88 (Conv2D)             (None, None, None,   590080      ['add_18[0][0]']
#                                 256)
#
#  conv2d_31 (Conv2D)             (None, None, None,   8256        ['up_sampling2d_1[0][0]']
#                                 64)
#
#  conv2d_30 (Conv2D)             (None, None, None,   8256        ['up_sampling2d[0][0]']
#                                 64)
#
#  conv2d_39 (Conv2D)             (None, None, None,   8256        ['up_sampling2d_5[0][0]']
#                                 64)
#
#  conv2d_38 (Conv2D)             (None, None, None,   8256        ['up_sampling2d_4[0][0]']
#                                 64)
#
#  conv2d_89 (Conv2D)             (None, None, None,   590080      ['conv2d_88[0][0]']
#                                 256)
#
#  add_5 (Add)                    (None, None, None,   0           ['conv2d_31[0][0]',
#                                 64)                               'conv2d_30[0][0]']
#
#  add_7 (Add)                    (None, None, None,   0           ['conv2d_39[0][0]',
#                                 64)                               'conv2d_38[0][0]']
#
#  tf.math.reduce_max_5 (TFOpLamb  (None, None, None)  0           ['conv2d_89[0][0]']
#  da)
#
#  tf.math.reduce_mean_5 (TFOpLam  (None, None, None)  0           ['conv2d_89[0][0]']
#  bda)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_2[0][0]',
#                                 64)                               'add_5[0][0]',
#                                                                   'add_7[0][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 256)         0           ['conv2d_89[0][0]']
#  obalAveragePooling2D)
#
#  tf.expand_dims_10 (TFOpLambda)  (None, None, None,   0          ['tf.math.reduce_max_5[0][0]']
#                                 1)
#
#  tf.expand_dims_11 (TFOpLambda)  (None, None, None,   0          ['tf.math.reduce_mean_5[0][0]']
#                                 1)
#
#  global_average_pooling2d_3 (Gl  (None, 64)          0           ['add_8[0][0]']
#  obalAveragePooling2D)
#
#  tf.reshape_8 (TFOpLambda)      (None, 1, 1, 256)    0           ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  concatenate_10 (Concatenate)   (None, None, None,   0           ['tf.expand_dims_10[0][0]',
#                                 2)                                'tf.expand_dims_11[0][0]']
#
#  tf.reshape_3 (TFOpLambda)      (None, 1, 1, 64)     0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  conv2d_90 (Conv2D)             (None, 1, 1, 32)     8224        ['tf.reshape_8[0][0]']
#
#  conv2d_92 (Conv2D)             (None, None, None,   3           ['concatenate_10[0][0]']
#                                 1)
#
#  conv2d_40 (Conv2D)             (None, 1, 1, 8)      520         ['tf.reshape_3[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 1, 1, 256)    8448        ['conv2d_90[0][0]']
#
#  tf.math.sigmoid_5 (TFOpLambda)  (None, None, None,   0          ['conv2d_92[0][0]']
#                                 1)
#
#  conv2d_41 (Conv2D)             (None, 1, 1, 64)     576         ['conv2d_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 1, 1, 64)     576         ['conv2d_40[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 1, 1, 64)     576         ['conv2d_40[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None, None, None,   0          ['conv2d_89[0][0]',
#  a)                             256)                              'conv2d_91[0][0]']
#
#  tf.math.multiply_20 (TFOpLambd  (None, None, None,   0          ['conv2d_89[0][0]',
#  a)                             256)                              'tf.math.sigmoid_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, None, None,   0          ['add_2[0][0]',
#  )                              64)                               'conv2d_41[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, None, None,   0          ['add_5[0][0]',
#  )                              64)                               'conv2d_42[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, None, None,   0          ['add_7[0][0]',
#  )                              64)                               'conv2d_43[0][0]']
#
#  concatenate_11 (Concatenate)   (None, None, None,   0           ['tf.math.multiply_19[0][0]',
#                                 512)                              'tf.math.multiply_20[0][0]']
#
#  add_9 (Add)                    (None, None, None,   0           ['tf.math.multiply_6[0][0]',
#                                 64)                               'tf.math.multiply_7[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  conv2d_93 (Conv2D)             (None, None, None,   131328      ['concatenate_11[0][0]']
#                                 256)
#
#  conv2d_72 (Conv2D)             (None, None, None,   36928       ['add_9[0][0]']
#                                 64)
#
#  add_22 (Add)                   (None, None, None,   0           ['add_18[0][0]',
#                                 256)                              'conv2d_93[0][0]']
#
#  conv2d_73 (Conv2D)             (None, None, None,   36928       ['conv2d_72[0][0]']
#                                 64)
#
#  conv2d_94 (Conv2D)             (None, None, None,   65792       ['add_22[0][0]']
#                                 256)
#
#  tf.math.reduce_max_3 (TFOpLamb  (None, None, None)  0           ['conv2d_73[0][0]']
#  da)
#
#  tf.math.reduce_mean_3 (TFOpLam  (None, None, None)  0           ['conv2d_73[0][0]']
#  bda)
#
#  conv2d_95 (Conv2D)             (None, None, None,   590080      ['conv2d_94[0][0]']
#                                 256)
#
#  global_average_pooling2d_6 (Gl  (None, 64)          0           ['conv2d_73[0][0]']
#  obalAveragePooling2D)
#
#  tf.expand_dims_6 (TFOpLambda)  (None, None, None,   0           ['tf.math.reduce_max_3[0][0]']
#                                 1)
#
#  tf.expand_dims_7 (TFOpLambda)  (None, None, None,   0           ['tf.math.reduce_mean_3[0][0]']
#                                 1)
#
#  up_sampling2d_11 (UpSampling2D  (None, None, None,   0          ['add_22[0][0]']
#  )                              256)
#
#  up_sampling2d_10 (UpSampling2D  (None, None, None,   0          ['conv2d_95[0][0]']
#  )                              256)
#
#  tf.reshape_6 (TFOpLambda)      (None, 1, 1, 64)     0           ['global_average_pooling2d_6[0][0
# ...
#  da)                            64)                               'conv2d_572[0][0]']
#
#  concatenate_71 (Concatenate)   (None, None, None,   0           ['tf.math.multiply_139[0][0]',
#                                 512)                              'tf.math.multiply_140[0][0]']
#
#  add_151 (Add)                  (None, None, None,   0           ['tf.math.multiply_126[0][0]',
#                                 64)                               'tf.math.multiply_127[0][0]',
#                                                                   'tf.math.multiply_128[0][0]']
#
#  conv2d_622 (Conv2D)            (None, None, None,   131328      ['concatenate_71[0][0]']
#                                 256)
#
#  conv2d_601 (Conv2D)            (None, None, None,   36928       ['add_151[0][0]']
#                                 64)
#
#  add_164 (Add)                  (None, None, None,   0           ['add_160[0][0]',
#                                 256)                              'conv2d_622[0][0]']
#
#  conv2d_602 (Conv2D)            (None, None, None,   36928       ['conv2d_601[0][0]']
#                                 64)
#
#  conv2d_623 (Conv2D)            (None, None, None,   65792       ['add_164[0][0]']
#                                 256)
#
#  tf.math.reduce_max_33 (TFOpLam  (None, None, None)  0           ['conv2d_602[0][0]']
#  bda)
#
#  tf.math.reduce_mean_33 (TFOpLa  (None, None, None)  0           ['conv2d_602[0][0]']
#  mbda)
#
#  conv2d_624 (Conv2D)            (None, None, None,   590080      ['conv2d_623[0][0]']
#                                 256)
#
#  global_average_pooling2d_56 (G  (None, 64)          0           ['conv2d_602[0][0]']
#  lobalAveragePooling2D)
#
#  tf.expand_dims_66 (TFOpLambda)  (None, None, None,   0          ['tf.math.reduce_max_33[0][0]']
#                                 1)
#
#  tf.expand_dims_67 (TFOpLambda)  (None, None, None,   0          ['tf.math.reduce_mean_33[0][0]']
#                                 1)
#
#  up_sampling2d_81 (UpSampling2D  (None, None, None,   0          ['add_164[0][0]']
#  )                              256)
#
#  up_sampling2d_80 (UpSampling2D  (None, None, None,   0          ['conv2d_624[0][0]']
#  )                              256)
#
#  tf.reshape_56 (TFOpLambda)     (None, 1, 1, 64)     0           ['global_average_pooling2d_56[0][
#                                                                  0]']
#
#  concatenate_66 (Concatenate)   (None, None, None,   0           ['tf.expand_dims_66[0][0]',
#                                 2)                                'tf.expand_dims_67[0][0]']
#
#  conv2d_626 (Conv2D)            (None, None, None,   32896       ['up_sampling2d_81[0][0]']
#                                 128)
#
#  conv2d_625 (Conv2D)            (None, None, None,   32896       ['up_sampling2d_80[0][0]']
#                                 128)
#
#  conv2d_603 (Conv2D)            (None, 1, 1, 8)      520         ['tf.reshape_56[0][0]']
#
#  conv2d_605 (Conv2D)            (None, None, None,   3           ['concatenate_66[0][0]']
#                                 1)
#
#  add_165 (Add)                  (None, None, None,   0           ['conv2d_626[0][0]',
#                                 128)                              'conv2d_625[0][0]']
#
#  conv2d_604 (Conv2D)            (None, 1, 1, 64)     576         ['conv2d_603[0][0]']
#
#  tf.math.sigmoid_33 (TFOpLambda  (None, None, None,   0          ['conv2d_605[0][0]']
#  )                              1)
#
#  conv2d_627 (Conv2D)            (None, None, None,   16512       ['add_165[0][0]']
#                                 128)
#
#  tf.math.multiply_135 (TFOpLamb  (None, None, None,   0          ['conv2d_602[0][0]',
#  da)                            64)                               'conv2d_604[0][0]']
#
#  tf.math.multiply_136 (TFOpLamb  (None, None, None,   0          ['conv2d_602[0][0]',
#  da)                            64)                               'tf.math.sigmoid_33[0][0]']
#
#  conv2d_628 (Conv2D)            (None, None, None,   147584      ['conv2d_627[0][0]']
#                                 128)
#
#  concatenate_67 (Concatenate)   (None, None, None,   0           ['tf.math.multiply_135[0][0]',
#                                 128)                              'tf.math.multiply_136[0][0]']
#
#  up_sampling2d_83 (UpSampling2D  (None, None, None,   0          ['add_165[0][0]']
#  )                              128)
#
#  up_sampling2d_82 (UpSampling2D  (None, None, None,   0          ['conv2d_628[0][0]']
#  )                              128)
#
#  conv2d_606 (Conv2D)            (None, None, None,   8256        ['concatenate_67[0][0]']
#                                 64)
#
#  conv2d_630 (Conv2D)            (None, None, None,   8256        ['up_sampling2d_83[0][0]']
#                                 64)
#
#  conv2d_629 (Conv2D)            (None, None, None,   8256        ['up_sampling2d_82[0][0]']
#                                 64)
#
#  add_161 (Add)                  (None, None, None,   0           ['add_151[0][0]',
#                                 64)                               'conv2d_606[0][0]']
#
#  add_166 (Add)                  (None, None, None,   0           ['conv2d_630[0][0]',
#                                 64)                               'conv2d_629[0][0]']
#
#  add_167 (Add)                  (None, None, None,   0           ['add_161[0][0]',
#                                 64)                               'add_166[0][0]',
#                                                                   'add_166[0][0]']
#
#  global_average_pooling2d_59 (G  (None, 64)          0           ['add_167[0][0]']
#  lobalAveragePooling2D)
#
#  tf.reshape_59 (TFOpLambda)     (None, 1, 1, 64)     0           ['global_average_pooling2d_59[0][
#                                                                  0]']
#
#  conv2d_631 (Conv2D)            (None, 1, 1, 8)      520         ['tf.reshape_59[0][0]']
#
#  conv2d_632 (Conv2D)            (None, 1, 1, 64)     576         ['conv2d_631[0][0]']
#
#  conv2d_633 (Conv2D)            (None, 1, 1, 64)     576         ['conv2d_631[0][0]']
#
#  conv2d_634 (Conv2D)            (None, 1, 1, 64)     576         ['conv2d_631[0][0]']
#
#  tf.math.multiply_141 (TFOpLamb  (None, None, None,   0          ['add_161[0][0]',
#  da)                            64)                               'conv2d_632[0][0]']
#
#  tf.math.multiply_142 (TFOpLamb  (None, None, None,   0          ['add_166[0][0]',
#  da)                            64)                               'conv2d_633[0][0]']
#
#  tf.math.multiply_143 (TFOpLamb  (None, None, None,   0          ['add_166[0][0]',
#  da)                            64)                               'conv2d_634[0][0]']
#
#  add_168 (Add)                  (None, None, None,   0           ['tf.math.multiply_141[0][0]',
#                                 64)                               'tf.math.multiply_142[0][0]',
#                                                                   'tf.math.multiply_143[0][0]']
#
#  conv2d_635 (Conv2D)            (None, None, None,   36928       ['add_168[0][0]']
#                                 64)
#
#  add_169 (Add)                  (None, None, None,   0           ['add_141[0][0]',
#                                 64)                               'conv2d_635[0][0]']
#
#  conv2d_636 (Conv2D)            (None, None, None,   36928       ['add_169[0][0]']
#                                 64)
#
#  add_170 (Add)                  (None, None, None,   0           ['conv2d_636[0][0]',
#                                 64)                               'add_113[0][0]']
#
#  conv2d_637 (Conv2D)            (None, None, None,   1731        ['add_170[0][0]']
#                                 3)
#
#  add_171 (Add)                  (None, None, None,   0           ['input_1[0][0]',
#                                 3)                                'conv2d_637[0][0]']
#
# ==================================================================================================
# Total params: 36,351,613
# Trainable params: 36,351,613
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def charbonnier_loss(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + tf.square(1e-3)))


def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=255.0)

# %%
optimizer = keras.optimizers.Adam(learning_rate=1e-4)
model.compile(
    optimizer=optimizer, loss=charbonnier_loss, metrics=[peak_signal_noise_ratio]
)

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_peak_signal_noise_ratio",
            factor=0.5,
            patience=5,
            verbose=1,
            min_delta=1e-7,
            mode="max",
        )
    ],
)
# Out:
# 2022-01-06 11:48:46.984279: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/50
# 2022-01-06 11:48:55.247748: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 150/150 [==============================] - ETA: 0s - loss: 0.1877 - peak_signal_noise_ratio: 62.6606
# 2022-01-06 11:55:51.530618: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 150/150 [==============================] - 483s 3s/step - loss: 0.1877 - peak_signal_noise_ratio: 62.6606 - val_loss: 0.1247 - val_peak_signal_noise_ratio: 65.5330 - lr: 1.0000e-04
# Epoch 2/50
# 150/150 [==============================] - 391s 3s/step - loss: 0.1677 - peak_signal_noise_ratio: 63.6882 - val_loss: 0.1164 - val_peak_signal_noise_ratio: 66.5715 - lr: 1.0000e-04
# Epoch 3/50
# 150/150 [==============================] - 410s 3s/step - loss: 0.1637 - peak_signal_noise_ratio: 63.9580 - val_loss: 0.1231 - val_peak_signal_noise_ratio: 65.8251 - lr: 1.0000e-04
# Epoch 4/50
# 150/150 [==============================] - 418s 3s/step - loss: 0.1540 - peak_signal_noise_ratio: 64.6186 - val_loss: 0.1108 - val_peak_signal_noise_ratio: 66.8482 - lr: 1.0000e-04
# Epoch 5/50
# 150/150 [==============================] - 449s 3s/step - loss: 0.1529 - peak_signal_noise_ratio: 64.5790 - val_loss: 0.1108 - val_peak_signal_noise_ratio: 66.9826 - lr: 1.0000e-04
# Epoch 6/50
# 150/150 [==============================] - 469s 3s/step - loss: 0.1372 - peak_signal_noise_ratio: 65.3402 - val_loss: 0.1147 - val_peak_signal_noise_ratio: 66.5948 - lr: 1.0000e-04
# Epoch 7/50
# 150/150 [==============================] - 468s 3s/step - loss: 0.1333 - peak_signal_noise_ratio: 65.6643 - val_loss: 0.1128 - val_peak_signal_noise_ratio: 66.9933 - lr: 1.0000e-04
# Epoch 8/50
# 150/150 [==============================] - 476s 3s/step - loss: 0.1401 - peak_signal_noise_ratio: 65.4244 - val_loss: 0.1136 - val_peak_signal_noise_ratio: 66.9696 - lr: 1.0000e-04
# Epoch 9/50
# 150/150 [==============================] - 481s 3s/step - loss: 0.1296 - peak_signal_noise_ratio: 65.9991 - val_loss: 0.1115 - val_peak_signal_noise_ratio: 67.1354 - lr: 1.0000e-04
# Epoch 10/50
# 150/150 [==============================] - 507s 3s/step - loss: 0.1326 - peak_signal_noise_ratio: 65.8942 - val_loss: 0.1018 - val_peak_signal_noise_ratio: 68.0632 - lr: 1.0000e-04
# Epoch 11/50
# 150/150 [==============================] - 485s 3s/step - loss: 0.1311 - peak_signal_noise_ratio: 65.9143 - val_loss: 0.1072 - val_peak_signal_noise_ratio: 67.4969 - lr: 1.0000e-04
# Epoch 12/50
# 150/150 [==============================] - 476s 3s/step - loss: 0.1272 - peak_signal_noise_ratio: 66.1361 - val_loss: 0.1001 - val_peak_signal_noise_ratio: 67.9653 - lr: 1.0000e-04
# Epoch 13/50
# 150/150 [==============================] - 479s 3s/step - loss: 0.1225 - peak_signal_noise_ratio: 66.5334 - val_loss: 0.1018 - val_peak_signal_noise_ratio: 67.9352 - lr: 1.0000e-04
# Epoch 14/50
# 150/150 [==============================] - 475s 3s/step - loss: 0.1202 - peak_signal_noise_ratio: 66.6937 - val_loss: 0.1019 - val_peak_signal_noise_ratio: 68.0896 - lr: 1.0000e-04
# Epoch 15/50
# 150/150 [==============================] - 473s 3s/step - loss: 0.1224 - peak_signal_noise_ratio: 66.6926 - val_loss: 0.1042 - val_peak_signal_noise_ratio: 67.7046 - lr: 1.0000e-04
# Epoch 16/50
# 150/150 [==============================] - 498s 3s/step - loss: 0.1280 - peak_signal_noise_ratio: 66.0956 - val_loss: 0.1118 - val_peak_signal_noise_ratio: 67.0522 - lr: 1.0000e-04
# Epoch 17/50
# 150/150 [==============================] - 456s 3s/step - loss: 0.1189 - peak_signal_noise_ratio: 66.8623 - val_loss: 0.1038 - val_peak_signal_noise_ratio: 67.9298 - lr: 1.0000e-04
# Epoch 18/50
# 150/150 [==============================] - 460s 3s/step - loss: 0.1203 - peak_signal_noise_ratio: 66.7067 - val_loss: 0.1056 - val_peak_signal_noise_ratio: 68.0021 - lr: 1.0000e-04
# Epoch 19/50
# 150/150 [==============================] - 453s 3s/step - loss: 0.1177 - peak_signal_noise_ratio: 66.8331 - val_loss: 0.0991 - val_peak_signal_noise_ratio: 68.3818 - lr: 1.0000e-04
# Epoch 20/50
# 150/150 [==============================] - 463s 3s/step - loss: 0.1160 - peak_signal_noise_ratio: 67.1051 - val_loss: 0.0979 - val_peak_signal_noise_ratio: 68.1636 - lr: 1.0000e-04
# Epoch 21/50
# 150/150 [==============================] - 434s 3s/step - loss: 0.1109 - peak_signal_noise_ratio: 67.4798 - val_loss: 0.0986 - val_peak_signal_noise_ratio: 68.3695 - lr: 1.0000e-04
# Epoch 22/50
# 150/150 [==============================] - 430s 3s/step - loss: 0.1153 - peak_signal_noise_ratio: 66.9504 - val_loss: 0.1013 - val_peak_signal_noise_ratio: 67.9853 - lr: 1.0000e-04
# Epoch 23/50
# 150/150 [==============================] - 449s 3s/step - loss: 0.1190 - peak_signal_noise_ratio: 66.8620 - val_loss: 0.1034 - val_peak_signal_noise_ratio: 67.8065 - lr: 1.0000e-04
# Epoch 24/50
# 150/150 [==============================] - ETA: 0s - loss: 0.1190 - peak_signal_noise_ratio: 67.0046
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 150/150 [==============================] - 1424s 10s/step - loss: 0.1190 - peak_signal_noise_ratio: 67.0046 - val_loss: 0.1013 - val_peak_signal_noise_ratio: 68.0543 - lr: 1.0000e-04
# Epoch 25/50
# 150/150 [==============================] - 1073s 7s/step - loss: 0.1105 - peak_signal_noise_ratio: 67.4093 - val_loss: 0.0984 - val_peak_signal_noise_ratio: 68.4037 - lr: 5.0000e-05
# Epoch 26/50
# 150/150 [==============================] - 366s 2s/step - loss: 0.1228 - peak_signal_noise_ratio: 66.5489 - val_loss: 0.1164 - val_peak_signal_noise_ratio: 67.0483 - lr: 5.0000e-05
# Epoch 27/50
# 150/150 [==============================] - 375s 2s/step - loss: 0.1147 - peak_signal_noise_ratio: 67.1228 - val_loss: 0.0956 - val_peak_signal_noise_ratio: 68.4948 - lr: 5.0000e-05
# Epoch 28/50
# 150/150 [==============================] - 400s 3s/step - loss: 0.1078 - peak_signal_noise_ratio: 67.6553 - val_loss: 0.1010 - val_peak_signal_noise_ratio: 67.8620 - lr: 5.0000e-05
# Epoch 29/50
# 150/150 [==============================] - 423s 3s/step - loss: 0.1215 - peak_signal_noise_ratio: 66.7453 - val_loss: 0.1003 - val_peak_signal_noise_ratio: 67.9469 - lr: 5.0000e-05
# Epoch 30/50
# 150/150 [==============================] - 914s 6s/step - loss: 0.1145 - peak_signal_noise_ratio: 67.1534 - val_loss: 0.0927 - val_peak_signal_noise_ratio: 68.6336 - lr: 5.0000e-05
# Epoch 31/50
# 150/150 [==============================] - 365s 2s/step - loss: 0.1124 - peak_signal_noise_ratio: 67.2992 - val_loss: 0.0968 - val_peak_signal_noise_ratio: 68.4511 - lr: 5.0000e-05
# Epoch 32/50
# 150/150 [==============================] - 378s 3s/step - loss: 0.1141 - peak_signal_noise_ratio: 67.1269 - val_loss: 0.0987 - val_peak_signal_noise_ratio: 68.0717 - lr: 5.0000e-05
# Epoch 33/50
# 150/150 [==============================] - 424s 3s/step - loss: 0.1052 - peak_signal_noise_ratio: 67.6156 - val_loss: 0.0960 - val_peak_signal_noise_ratio: 68.5413 - lr: 5.0000e-05
# Epoch 34/50
# 150/150 [==============================] - 496s 3s/step - loss: 0.1129 - peak_signal_noise_ratio: 67.1691 - val_loss: 0.1031 - val_peak_signal_noise_ratio: 67.8048 - lr: 5.0000e-05
# Epoch 35/50
# 150/150 [==============================] - ETA: 0s - loss: 0.1119 - peak_signal_noise_ratio: 67.2811
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 150/150 [==============================] - 1182s 2s/step - loss: 0.1119 - peak_signal_noise_ratio: 67.2811 - val_loss: 0.0929 - val_peak_signal_noise_ratio: 68.5351 - lr: 5.0000e-05
# Epoch 36/50
# 150/150 [==============================] - 383s 3s/step - loss: 0.1116 - peak_signal_noise_ratio: 67.3437 - val_loss: 0.1028 - val_peak_signal_noise_ratio: 67.7775 - lr: 2.5000e-05
# Epoch 37/50
# 150/150 [==============================] - 430s 3s/step - loss: 0.1075 - peak_signal_noise_ratio: 67.6364 - val_loss: 0.1040 - val_peak_signal_noise_ratio: 67.6305 - lr: 2.5000e-05
# Epoch 38/50
# 150/150 [==============================] - 504s 3s/step - loss: 0.1007 - peak_signal_noise_ratio: 68.1335 - val_loss: 0.0991 - val_peak_signal_noise_ratio: 68.0074 - lr: 2.5000e-05
# Epoch 39/50
# 150/150 [==============================] - 1717s 11s/step - loss: 0.1113 - peak_signal_noise_ratio: 67.3274 - val_loss: 0.1076 - val_peak_signal_noise_ratio: 67.4236 - lr: 2.5000e-05
# Epoch 40/50
# 150/150 [==============================] - ETA: 0s - loss: 0.1071 - peak_signal_noise_ratio: 67.6315
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 150/150 [==============================] - 382s 3s/step - loss: 0.1071 - peak_signal_noise_ratio: 67.6315 - val_loss: 0.1031 - val_peak_signal_noise_ratio: 67.7946 - lr: 2.5000e-05
# Epoch 41/50
# 150/150 [==============================] - 424s 3s/step - loss: 0.1078 - peak_signal_noise_ratio: 67.7674 - val_loss: 0.1075 - val_peak_signal_noise_ratio: 67.6743 - lr: 1.2500e-05
# Epoch 42/50
# 150/150 [==============================] - 452s 3s/step - loss: 0.1069 - peak_signal_noise_ratio: 67.8198 - val_loss: 0.1048 - val_peak_signal_noise_ratio: 67.7711 - lr: 1.2500e-05
# Epoch 43/50
# 150/150 [==============================] - 443s 3s/step - loss: 0.1078 - peak_signal_noise_ratio: 67.6088 - val_loss: 0.1068 - val_peak_signal_noise_ratio: 67.7063 - lr: 1.2500e-05
# Epoch 44/50
# 150/150 [==============================] - 446s 3s/step - loss: 0.1072 - peak_signal_noise_ratio: 67.6750 - val_loss: 0.1123 - val_peak_signal_noise_ratio: 67.4584 - lr: 1.2500e-05
# Epoch 45/50
# 150/150 [==============================] - ETA: 0s - loss: 0.1024 - peak_signal_noise_ratio: 68.1254
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 150/150 [==============================] - 464s 3s/step - loss: 0.1024 - peak_signal_noise_ratio: 68.1254 - val_loss: 0.0999 - val_peak_signal_noise_ratio: 68.2074 - lr: 1.2500e-05
# Epoch 46/50
# 150/150 [==============================] - 543s 4s/step - loss: 0.1089 - peak_signal_noise_ratio: 67.5326 - val_loss: 0.1028 - val_peak_signal_noise_ratio: 67.9796 - lr: 6.2500e-06
# Epoch 47/50
# 150/150 [==============================] - 436s 3s/step - loss: 0.1042 - peak_signal_noise_ratio: 67.9765 - val_loss: 0.1052 - val_peak_signal_noise_ratio: 67.9195 - lr: 6.2500e-06
# Epoch 48/50
# 150/150 [==============================] - 463s 3s/step - loss: 0.1037 - peak_signal_noise_ratio: 67.9673 - val_loss: 0.1092 - val_peak_signal_noise_ratio: 67.3513 - lr: 6.2500e-06
# Epoch 49/50
# 150/150 [==============================] - 469s 3s/step - loss: 0.1010 - peak_signal_noise_ratio: 68.1235 - val_loss: 0.1058 - val_peak_signal_noise_ratio: 67.7970 - lr: 6.2500e-06
# Epoch 50/50
# 150/150 [==============================] - ETA: 0s - loss: 0.0974 - peak_signal_noise_ratio: 68.3898
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 150/150 [==============================] - 1540s 10s/step - loss: 0.0974 - peak_signal_noise_ratio: 68.3898 - val_loss: 0.1068 - val_peak_signal_noise_ratio: 67.6289 - lr: 6.2500e-06

# %%
model.save("my_model")
model.save("my_h5_model.h5")
# Out:
# 2022-01-06 19:27:17.950863: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: my_model/assets
# /Users/beomus/python/captcha-ocr/env/lib/python3.9/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /Users/beomus/python/captcha-ocr/env/lib/python3.9/site-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(history.history["peak_signal_noise_ratio"], label="train_psnr")
plt.plot(history.history["val_peak_signal_noise_ratio"], label="val_psnr")
plt.xlabel("Epochs")
plt.ylabel("PSNR")
plt.title("Train and Validation PSNR Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
def plot_results(images, titles, figure_size=(12, 12)):
    fig = plt.figure(figsize=figure_size)
    for i in range(len(images)):
        fig.add_subplot(1, len(images), i + 1).set_title(titles[i])
        _ = plt.imshow(images[i])
        plt.axis("off")
    plt.show()


def infer(original_image):
    image = keras.preprocessing.image.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output = model.predict(image)
    output_image = output[0] * 255.0
    output_image = output_image.clip(0, 255)
    output_image = output_image.reshape(
        (np.shape(output_image)[0], np.shape(output_image)[1], 3)
    )
    output_image = Image.fromarray(np.uint8(output_image))
    original_image = Image.fromarray(np.uint8(original_image))
    return output_image

# %%
for low_light_image in random.sample(test_low_light_images, 6):
    original_image = Image.open(low_light_image)
    enhanced_image = infer(original_image)
    plot_results(
        [original_image, ImageOps.autocontrast(original_image), enhanced_image],
        ["Original", "PIL Autocontrast", "MIRNet Enhanced"],
        (20, 12),
    )
# Out:
# 2022-01-06 19:27:51.179526: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
